# %%
import shutil
import gc
import torch
import pandas as pd
import os

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.widgets import *

# %%
from fastai.callbacks import *

# %%
df_train = pd.read_csv('/Users/harrisonmiller/Documents/flatiron/Projects/MyProjects/MURA-v1.1/train_image_paths.csv', header = None, names = ['image'])
df_train.image[0]
# Out:
# 'MURA-v1.1/train/XR_SHOULDER/patient00001/study1_positive/image1.png'

# %%
df_valid = pd.read_csv('/Users/harrisonmiller/Documents/flatiron/Projects/MyProjects/MURA-v1.1/valid_image_paths.csv',header = None, names = ['image'])
df_valid.image[0]
# Out:
# 'MURA-v1.1/valid/XR_WRIST/patient11185/study1_positive/image1.png'

# %%
df_train_label = pd.read_csv('/Users/harrisonmiller/Documents/flatiron/Projects/MyProjects/MURA-v1.1/train_labeled_studies.csv',header = None, names = ['image','label'])
df_train_label.head()
# Out:
#                                                image  label
# 0  MURA-v1.1/train/XR_SHOULDER/patient00001/study...      1
# 1  MURA-v1.1/train/XR_SHOULDER/patient00002/study...      1
# 2  MURA-v1.1/train/XR_SHOULDER/patient00003/study...      1
# 3  MURA-v1.1/train/XR_SHOULDER/patient00004/study...      1
# 4  MURA-v1.1/train/XR_SHOULDER/patient00005/study...      1

# %%
import pandas_profiling

# %%
df_train_label.profile_report()
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.3.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...

# %%
# path_train = '/Users/harrisonmiller/Documents/flatiron/Projects/MyProjects/MURA-v1.1/data2/train'
# path_valid = '/Users/harrisonmiller/Documents/flatiron/Projects/MyProjects/MURA-v1.1/data2/valid'
# path_train.mkdir(parents = True, exist_ok = True)
# path_valid.mkdir(parents=True, exist_ok=True)

# %%
Config.data_path()
# Out:
# PosixPath('/Users/harrisonmiller/.fastai/data')

# %%
path = Config.data_path() /'Users/harrisonmiller/Documents/flatiron/Projects/MyProjects/MURA-v1.1'
path.ls()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-31-c88e92f702f9> in <module>
#       1 path = Config.data_path() /'Users/harrisonmiller/Documents/flatiron/Projects/MyProjects/MURA-v1.1'
# ----> 2 path.ls()
#
# //anaconda3/lib/python3.7/site-packages/fastai/core.py in <lambda>(x)
#     234     return np.arange(len(x))
#     235
# --> 236 Path.ls = lambda x: list(x.iterdir())
#     237
#     238 def join_path(fname:PathOrStr, path:PathOrStr='.')->Path:
#
# //anaconda3/lib/python3.7/pathlib.py in iterdir(self)
#    1081         if self._closed:
#    1082             self._raise_closed()
# -> 1083         for name in self._accessor.listdir(self):
#    1084             if name in {'.', '..'}:
#    1085                 # Yielding a path object for these makes little sense
#
# ...
